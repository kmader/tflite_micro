# %% [markdown]
# ## Run the test
# Show that the speech test runs

# %%
# !tensorflow/tensorflow/lite/experimental/micro/tools/make/gen/linux_x86_64/bin/micro_speech_test
# Out:
# Testing TestInvoke
# Ran successfully
#
# 1/1 tests passed
# ~~~ALL TESTS PASSED~~~

# %% [markdown]
# ## Run all of the tests

# %%
from glob import glob
for k in glob('tensorflow/tensorflow/lite/experimental/micro/tools/make/gen/*/bin/*'):
    # !{k}
# Out:
# Testing TestCallability
# Heard foo (0) @0ms
# 1/1 tests passed
# ~~~ALL TESTS PASSED~~~
#
# Testing PcanGainControlTest_TestPcanGainControl
# 1/1 tests passed
# ~~~ALL TESTS PASSED~~~
#
# Testing TestInvoke
# Ran successfully
#
# 1/1 tests passed
# ~~~ALL TESTS PASSED~~~
#
# Testing TestOperations
# 1/1 tests passed
# ~~~ALL TESTS PASSED~~~
#
# Testing FrontendTest_CheckOutputValues
# Testing FrontendTest_CheckConsecutiveWindow
# Testing FrontendTest_CheckNotEnoughSamples
# 3/3 tests passed
# ~~~ALL TESTS PASSED~~~
#
# Testing TestSimpleFeaturesGenerator
# 1/1 tests passed
# ~~~ALL TESTS PASSED~~~
#
# Testing PreviousResultsQueueBasic
# Testing PreviousResultsQueuePushPop
# Testing RecognizeCommandsTestBasic
# Testing RecognizeCommandsTestFindCommands
# Testing RecognizeCommandsTestBadInputLength
# The results for recognition should contain 4 elements, but there are 3 in an 2-dimensional shape
# Testing RecognizeCommandsTestBadInputTimes
# ...
